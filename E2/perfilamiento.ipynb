# %% [markdown]
# ## PERFILAMIENTO
#
# Se realiza el perfilamiento de cada uno de los archivos

# %%
import os
import glob
import pandas as pd
import numpy as np
import pandas_profiling as pd_pf

# %%
df = pd.read_excel("datos_originales/aeropuertos.xlsx")
profile = pd_pf.ProfileReport(df)
profile.to_file("reportes/aeropuertos.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=37.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…

# %%
df = pd.read_excel("datos_originales/Cobertura de Aerea de Centros Poblados por Categoria de Aeropuerto.xlsx")
profile = pd_pf.ProfileReport(df)
profile.to_file("reportes/Cobertura de Aerea de Centros Poblados por Categoria de Aeropuerto.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=27.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…

# %%
df = pd.read_excel("datos_originales/Geoportal del DANE - Codificación Divipola.xlsx")
profile = pd_pf.ProfileReport(df)
profile.to_file("reportes/Geoportal del DANE - Codificación Divipola.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=26.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…

# %%
df = pd.read_excel("datos_originales/Matriz de distancias entre aeropuertos y centros poblados de Colombia.xlsx")
profile = pd_pf.ProfileReport(df)
profile.to_file("reportes/Matriz de distancias entre aeropuertos y centros poblados de Colombia.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=775.0, style=ProgressStyle(descri…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3bc6c4ff98e8> in <module>
#       1 df = pd.read_excel("datos_originales/Matriz de distancias entre aeropuertos y centros poblados de Colombia.xlsx")
#       2 profile = pd_pf.ProfileReport(df)
# ----> 3 profile.to_file("reportes/Matriz de distancias entre aeropuertos y centros poblados de Colombia.html")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_file(self, output_file, silent)
#     254                 create_html_assets(output_file)
#     255
# --> 256             data = self.to_html()
#     257
#     258             if output_file.suffix != ".html":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_html(self)
#     357
#     358         """
# --> 359         return self.html
#     360
#     361     def to_json(self) -> str:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in html(self)
#     177     def html(self):
#     178         if self._html is None:
# --> 179             self._html = self._render_html()
#     180         return self._html
#     181
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in _render_html(self)
#     284         from pandas_profiling.report.presentation.flavours import HTMLReport
#     285
# --> 286         report = self.report
#     287
#     288         disable_progress_bar = not config["progress_bar"].get(bool)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in report(self)
#     171     def report(self):
#     172         if self._report is None:
# --> 173             self._report = get_report_structure(self.description_set)
#     174         return self._report
#     175
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in description_set(self)
#     152     def description_set(self):
#     153         if self._description_set is None:
# --> 154             self._description_set = describe_df(self.title, self.df, self._sample)
#     155         return self._description_set
#     156
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/model/describe.py in describe(title, df, sample)
#      88         for correlation_name in correlation_names:
#      89             pbar.set_postfix_str(f"Calculate {correlation_name} correlation")
# ---> 90             correlations[correlation_name] = calculate_correlation(
#      91                 df, variables, correlation_name
#      92             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/model/correlations.py in calculate_correlation(df, variables, correlation_name)
#     166             if len(selcols) > 1:
#     167                 try:
# --> 168                     correlation = df[selcols].phik_matrix(interval_cols=intcols)
#     169
#     170                     # Only do this if the column_order is set
#
# ~/opt/anaconda3/lib/python3.8/site-packages/phik/phik.py in phik_matrix(df, interval_cols, bins, quantile, noise_correction, dropna, drop_underflow, drop_overflow)
#     214     data_binned, binning_dict = bin_data(df_clean, cols=interval_cols_clean, bins=bins, quantile=quantile, retbins=True)
#     215
# --> 216     return phik_from_rebinned_df(
#     217         data_binned, noise_correction, dropna=dropna, drop_underflow=drop_underflow, drop_overflow=drop_overflow
#     218     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/phik/phik.py in phik_from_rebinned_df(data_binned, noise_correction, dropna, drop_underflow, drop_overflow)
#     141         ]
#     142     else:
# --> 143         phik_list = Parallel(n_jobs=NCORES)(
#     144             delayed(_calc_phik)(co, data_binned[list(co)], noise_correction)
#     145             for co in itertools.combinations_with_replacement(data_binned.columns.values, 2)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/opt/anaconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("datos_originales/aeropuertos_historico_data.csv",sep=';')
profile = pd_pf.ProfileReport(df)
profile.to_file("reportes/aeropuertos_historico_data.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=27.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…
